# %%
from PIL import Image
from fastai import *
from fastai.vision.widgets import *

# %%
def showImage(num):
    dest = 'image_{}.jpg'.format(num)
    im = Image.open(dest)
    im.to_thumb(128, 128)

# %%
dest = 'image_{}.jpg'.format(222)
im = Image.open(dest)
im.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85 at 0x4EAB630>
